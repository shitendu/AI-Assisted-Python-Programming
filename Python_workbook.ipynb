# %% [markdown]
# <a href="https://colab.research.google.com/github/shitendu/AI-Assisted-Python-Programming/blob/main/Python_workbook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Day 1 Task**

# %%
print("Om Namo Shibao!!")
# Out:
# Om Namo Shibao!!

# %%
import keyword
print("standard keyword=",len(keyword.kwlist))
print("soft keyword=" ,keyword.kwlist)
print("all keyword=" ,keyword.kwlist)
# Out:
# standard keyword= 35
# soft keyword= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']
# all keyword= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
Age=input("Enter Age")
print (Age)
# Out:
# Enter Age35
# 35

# %% [markdown]
# Variable and Data **Type**

# %%
x = 5
y = "Shitendu"
z = 11
print(x+z,y)
# Out:
# 16 Shitendu

# %%
x = 5
y = "Shitendu"
z = 11.6
print(type(x))
print(type(y))
print(type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
y1 = 2
print(y1)
print(type(y1))

y2=float(y1)
print(y2)
print(type(y2))

y3=str(y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'str'>

# %%
myname = "shitendu some"
my_dept = "ME"
_my_university = "SRU"
city = "Warangal"
print (myname,my_dept)
# Out:
# shitendu some ME

# %%
a=input("value of a")
b=input("value of b")
a=int(a)
b=int(b)
print("=======================")
print("sample calculator")
print("=======================")
print("Addition=", a+b)
print("=======================")
print("substration=", a-b)
print("=======================")
print("multiplication=", a*b)
print("=======================")
print("division=", a/b)
print("=======================")
# Out:
# value of a100
# value of b10
# ...
# sample calculator
# ...
# Addition= 110
# ...
# substration= 90
# ...
# multiplication= 1000
# ...
# division= 10.0
# ...

# %%
num1=10
num2=0
num3=10
str1="Good"
str2="Afternoon"
print("Status=",num1==num2)
print("Status=",num1==num3)
print("Status=",num1!=num2)
print("Status=",num1!=num2)
print("Status=",num1>num2)
print("Status=",num1<num2)
print("Status=",num1<=num2)
print("Status=",num1>=num2)
# Out:
# Status= False
# Status= True
# Status= True
# Status= True
# Status= True
# Status= False
# Status= False
# Status= True

# %%
userid=["ram","vvr"]
username=input("input user name")
if username in userid:
  print("valid user")
else:
  print("invalid user")
# Out:
# input user nameram
# valid user

# %%
#odd number check
num=input("enter number")
num=int(num)
if num%2==0:
  print("even number")
else:
  print("odd number")
# Out:
# enter number21
# odd number

# %%
#traffic signal check
num=input("light")
num=str(num)
if num=="red":
  print("Not Go")
else:
  print("Go")
# Out:
# lightyellow
# Go

# %%
#pass fail determine
num=input("enter a number")
num=int(num)
if num>=40 and num<50:
  print("Grade D")


else:
  print("fail")
# Out:
# enter a number39
# fail

# %%
#pass fail determine
num=input("enter a number")
num=float(num)
if num>=40 and num<50:
  print("Grade D")
if num>=50 and num<60:
  print("Grade C")
if num>=60 and num<70:
  print("Grade B")
if num>=70 and num<100:
  print("Grade A")
if num<40:
  print("fail")
# Out:
# enter a number40.5
# Grade D

# %%
#energy price calculation
num=input("enter a number")
num=int(num)
if num*2:
  print("energy price for residential customer", num*2)
if num*5:
   print("energy price for commersial customer",num*5)
if num*10:
   print("energy price for industrial customer",num*10)
# Out:
# enter a number3
# energy price for residential customer 6
# energy price for commersial customer 15
# energy price for industrial customer 30
